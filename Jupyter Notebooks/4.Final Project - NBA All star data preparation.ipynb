# %% [markdown]
# # Final Project - NBA All star data preparation

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## reading both df, all star and college players

# %%
# reading allstar data file from csv

all_star_df = pd.read_csv('all_star_rosters.csv', index_col = 0)
all_star_df.head()
# Out:
#                Name
# 0       Dwyane Wade
# 1      LeBron James
# 2     Allen Iverson
# 3  Shaquille O'Neal
# 4      Vince Carter

# %%
all_star_df.shape
# Out:
# (113, 1)

# %%
# reading college data clean file from csv

college_players = pd.read_csv('college_data.csv', index_col = 0)
college_players.head()
# Out:
#       player_name             school  GP  Min_per   ORtg   usg   eFG  TS_per  \
# 1   DeAndrae Ross               Troy   7     11.5   67.1  16.9  34.5   36.11
# 2   Pooh Williams           Utah St.  33     64.5  105.6  18.7  48.1   52.40
# 11     Dana Smith           Longwood  27     81.8   99.8  27.7  49.9   53.76
# 26  Carlos Strong  Boston University  35     76.2  118.1  16.4  58.8   60.93
# 27  Sherrod Smith  Boston University  29      9.5   60.7   6.9   8.3   14.93
#
#     FT_per  twoP_per  ...        bpm       mp    oreb    dreb     ast     stl  \
# 1    0.500     0.364  ... -10.394000  18.8571  0.5714  1.1429  1.4286  0.1429
# 2    0.815     0.394  ...   1.125160  26.0000  0.1515  1.4848  2.0909  0.2121
# 11   0.658     0.483  ...  -0.441037  32.7037  2.1481  4.9259  2.4074  0.8148
# 26   0.682     0.478  ...   6.077490  30.6857  1.3429  3.2286  1.8000  1.6571
# 27   0.300     0.100  ...  -4.128490   4.6207  0.1379  0.5862  0.2069  0.1034
#
# ...

# %% [markdown]
# ## get only drafted players from college

# %%
drafted_df=college_players.loc[college_players['drafted'] == 'Yes']

# %%
drafted_df.head()
# Out:
#          player_name       school  GP  Min_per   ORtg   usg   eFG  TS_per  \
# 48   Charles Jenkins      Hofstra  32     92.4  123.2  28.7  57.7   62.93
# 79    Vernon Macklin      Florida  37     59.7  107.5  24.3  59.3   57.77
# 167        Ryan Reid  Florida St.  31     54.8   97.5  18.3  49.1   51.58
# 171     Kyle Singler         Duke  37     86.9  112.3  23.5  49.1   53.64
# 172      Nolan Smith         Duke  37     85.1  114.0  30.8  50.8   56.40
#
#      FT_per  twoP_per  ...      bpm       mp    oreb    dreb     ast     stl  \
# 48    0.825     0.555  ...  7.09443  37.4062  0.5000  2.7188  4.6875  1.6562
# 79    0.451     0.593  ...  3.88301  24.4595  2.2162  3.1622  0.8108  0.3514
# 167   0.597     0.491  ...  2.50667  22.7097  1.8710  2.0968  1.1290  0.5806
# 171   0.806     0.497  ...  5.95265  34.7568  2.3784  4.4595  1.6216  0.9189
# 172   0.813     0.501  ...  7.92525  34.0270  1.1892  3.2973  5.1081  1.2162
#
#         blk      pts        role  drafted
# ...

# %% [markdown]
# ## feature engineering

# %% [markdown]
# ### create all star column in college players data drame based on names in allstar data frame

# %%
drafted_df['Allstar'] = np.where(drafted_df.player_name.isin(all_star_df.Name), 'Yes', 'No')
# Out:
# /var/folders/gd/t7jqq6zs1zl6b6b62cxdkccw0000gn/T/ipykernel_16982/3165909800.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drafted_df['Allstar'] = np.where(drafted_df.player_name.isin(all_star_df.Name), 'Yes', 'No')

# %%
drafted_df.reset_index()
# Out:
#      index         player_name          school  GP  Min_per   ORtg   usg  \
# 0       48     Charles Jenkins         Hofstra  32     92.4  123.2  28.7
# 1       79      Vernon Macklin         Florida  37     59.7  107.5  24.3
# 2      167           Ryan Reid     Florida St.  31     54.8   97.5  18.3
# 3      171        Kyle Singler            Duke  37     86.9  112.3  23.5
# 4      172         Nolan Smith            Duke  37     85.1  114.0  30.8
# ..     ...                 ...             ...  ..      ...    ...   ...
# 567  26794      Day'Ron Sharpe  North Carolina  29     47.9  101.9  27.5
# 568  26798      Isaiah Jackson        Kentucky  25     51.1  108.0  21.3
# 569  26893      Greg Brown III           Texas  26     48.9   91.7  25.8
# 570  26941        Keon Johnson       Tennessee  27     62.5   95.2  27.3
# 571  26979  Brandon Boston Jr.        Kentucky  25     75.9   96.4  21.4
#
#       eFG  TS_per  FT_per  ...       mp    oreb    dreb     ast     stl  \
# ...

# %%
drafted_df['Allstar'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# verify number of allstar players match with allstar df
drafted_df['Allstar'].value_counts()
# Out:
# No     541
# Yes     31
# Name: Allstar, dtype: int64

# %%
drafted_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 572 entries, 48 to 26979
# Data columns (total 27 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   player_name  572 non-null    object
#  1   school       572 non-null    object
#  2   GP           572 non-null    int64
#  3   Min_per      572 non-null    float64
#  4   ORtg         572 non-null    float64
#  5   usg          572 non-null    float64
#  6   eFG          572 non-null    float64
#  7   TS_per       572 non-null    float64
#  8   FT_per       572 non-null    float64
#  9   twoP_per     572 non-null    float64
#  10  TP_per       572 non-null    float64
#  11  yr           572 non-null    int64
#  12  ht           572 non-null    int64
#  13  ast/tov      572 non-null    float64
#  14  pick         572 non-null    float64
#  15  drtg         572 non-null    float64
#  16  bpm          572 non-null    float64
#  17  mp           572 non-null    float64
# ...

# %%
drafted_df=drafted_df.reset_index(drop=True)

# %%
drafted_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 27 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   player_name  572 non-null    object
#  1   school       572 non-null    object
#  2   GP           572 non-null    int64
#  3   Min_per      572 non-null    float64
#  4   ORtg         572 non-null    float64
#  5   usg          572 non-null    float64
#  6   eFG          572 non-null    float64
#  7   TS_per       572 non-null    float64
#  8   FT_per       572 non-null    float64
#  9   twoP_per     572 non-null    float64
#  10  TP_per       572 non-null    float64
#  11  yr           572 non-null    int64
#  12  ht           572 non-null    int64
#  13  ast/tov      572 non-null    float64
#  14  pick         572 non-null    float64
#  15  drtg         572 non-null    float64
#  16  bpm          572 non-null    float64
#  17  mp           572 non-null    float64
# ...

# %%
# showing allstar players, non college, overseas players or players drafted before 2008 won't appear
drafted_df.loc[drafted_df['Allstar'] == 'Yes']
# Out:
#             player_name          school  GP  Min_per   ORtg   usg   eFG  \
# 45       Damian Lillard       Weber St.  30     87.2  122.3  32.3  54.5
# 52       Nikola Vucevic             USC  34     87.0  115.9  25.1  53.9
# 55          Paul George      Fresno St.  28     72.6  105.6  27.3  51.0
# 57       Gordon Hayward          Butler  37     81.2  113.3  24.4  52.7
# 72        Klay Thompson  Washington St.  34     83.0  107.6  31.9  52.5
# 75       Draymond Green    Michigan St.  37     82.8  107.3  28.2  50.4
# 77         Kemba Walker     Connecticut  41     92.4  117.8  31.5  47.8
# 78         Jimmy Butler       Marquette  37     86.3  122.0  21.2  51.6
# 104     Khris Middleton       Texas A&M  19     44.3   96.0  28.6  45.1
# 105           John Wall        Kentucky  37     83.9  108.7  26.9  50.3
# 109       Kawhi Leonard   San Diego St.  34     79.6  108.7  27.7  46.3
# 112    DeMarcus Cousins        Kentucky  38     58.2  113.5  30.8  56.0
# ...

# %%
#alldrafted college picks
drafted_df['pick'].value_counts()
# Out:
# 46.0    12
# 21.0    12
# 40.0    12
# 51.0    12
# 1.0     12
# 2.0     11
# 30.0    11
# 38.0    11
# 9.0     11
# 22.0    11
# 14.0    11
# 12.0    11
# 42.0    11
# 18.0    11
# 29.0    11
# 11.0    11
# 28.0    11
# 56.0    11
# 33.0    11
# 8.0     11
# 34.0    10
# 13.0    10
# 10.0    10
# 26.0    10
# 41.0    10
# 6.0     10
# 49.0    10
# 25.0    10
# 37.0    10
# 32.0    10
# 19.0     9
# 17.0     9
# 36.0     9
# 3.0      9
# 5.0      9
# 4.0      9
# 45.0     9
# 44.0     9
# 50.0     9
# 47.0     9
# 52.0     9
# 27.0     9
# 48.0     9
# 58.0     9
# 24.0     9
# 55.0     9
# 16.0     8
# 59.0     8
# 35.0     8
# 20.0     8
# 23.0     8
# 53.0     8
# 15.0     8
# 7.0      8
# 54.0     8
# 43.0     7
# 39.0     7
# 31.0     6
# 60.0     6
# 57.0     5
# Name: pick, dtype: int64

# %%
# converting pick column to integer
drafted_df[['pick']].astype(int)
# Out:
#      pick
# 0      44
# 1      52
# 2      57
# 3      33
# 4      21
# ..    ...
# 567    29
# 568    22
# 569    43
# 570    21
# 571    51
#
# [572 rows x 1 columns]

# %%
#saving to csv file
drafted_df.to_csv('drafted_vs_allstar.csv')
